# %% [markdown]
# # Part 1: Data Extraction and Database Design

# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import re
import time

# %%
url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"

# fetching the content of the page
response = requests.get(url)
if response.status_code == 200:
    page_content = response.text
    print("Successful success (code 200)! ! !")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
    page_content = ""
# Out:
# Successful success (code 200)! ! !

# %%
soup = BeautifulSoup(page_content, 'html.parser')
# for the first table in the page
table = soup.find('table', {'class': 'wikitable'})
if table:
    rows = table.find_all('tr')
else:
    print("No table found on the page.")
    rows = []

films_data = []

for row in rows[1:]:
    cols = row.find_all(['td', 'th'])
    if len(cols) < 5:
        continue

    title_col = cols[2].find('a')
    title = title_col.get_text(strip=True)
    release_year = cols[4].get_text(strip=True)
    box_office = cols[3].get_text(strip=True)
    film_link = title_col['href'] if title_col else None

    release_year = int(release_year)
    box_office = int(box_office.split("$")[1].replace(",", ""))  # from $123,456 to 123456

    # # remove any references in brackets
    # title = re.sub(r'\[.*?\]', '', title)
    # box_office = re.sub(r'\[.*?\]', '', box_office)

    films_data.append({
        'title': title,
        'release_year': release_year,
        'box_office': box_office,
        'film_link': film_link
    })

# %%
films_data
# Out:
# [{'title': 'Avatar',
#   'release_year': 2009,
#   'box_office': 2923706026,
#   'film_link': '/wiki/Avatar_(2009_film)'},
#  {'title': 'Avengers: Endgame',
#   'release_year': 2019,
#   'box_office': 2797501328,
#   'film_link': '/wiki/Avengers:_Endgame'},
#  {'title': 'Avatar: The Way of Water',
#   'release_year': 2022,
#   'box_office': 2320250281,
#   'film_link': '/wiki/Avatar:_The_Way_of_Water'},
#  {'title': 'Titanic',
#   'release_year': 1997,
#   'box_office': 2257844554,
#   'film_link': '/wiki/Titanic_(1997_film)'},
#  {'title': 'Star Wars: The Force Awakens',
#   'release_year': 2015,
#   'box_office': 2068223624,
#   'film_link': '/wiki/Star_Wars:_The_Force_Awakens'},
#  {'title': 'Avengers: Infinity War',
#   'release_year': 2018,
#   'box_office': 2048359754,
#   'film_link': '/wiki/Avengers:_Infinity_War'},
#  {'title': 'Ne Zha 2',
#   'release_year': 2025,
#   'box_office': 1940794560,
#   'film_link': '/wiki/Ne_Zha_2'},
#  {'title': 'Spider-Man: No Way Home',
#   'release_year': 2021,
#   'box_office': 1922598800,
#   'film_link': '/wiki/Spider-Man:_No_Way_Home'},
#  {'title': 'Inside Out 2',
#   'release_year': 2024,
#   'box_office': 1698863816,
#   'film_link': '/wiki/Inside_Out_2'},
#  {'title': 'Jurassic World',
#   'release_year': 2015,
#   'box_office': 1671537444,
#   'film_link': '/wiki/Jurassic_World'},
#  {'title': 'The Lion King',
#   'release_year': 2019,
#   'box_office': 1656943394,
#   'film_link': '/wiki/The_Lion_King_(2019_film)'},
#  {'title': 'The Avengers',
#   'release_year': 2012,
#   'box_office': 1518815515,
#   'film_link': '/wiki/The_Avengers_(2012_film)'},
#  {'title': 'Furious 7',
#   'release_year': 2015,
#   'box_office': 1515341399,
#   'film_link': '/wiki/Furious_7'},
#  {'title': 'Top Gun: Maverick',
#   'release_year': 2022,
#   'box_office': 1495696292,
#   'film_link': '/wiki/Top_Gun:_Maverick'},
#  {'title': 'Frozen 2',
#   'release_year': 2019,
#   'box_office': 1450026933,
#   'film_link': '/wiki/Frozen_2'},
#  {'title': 'Barbie',
#   'release_year': 2023,
#   'box_office': 1447038421,
#   'film_link': '/wiki/Barbie_(film)'},
#  {'title': 'Avengers: Age of Ultron',
#   'release_year': 2015,
#   'box_office': 1402809540,
#   'film_link': '/wiki/Avengers:_Age_of_Ultron'},
#  {'title': 'The Super Mario Bros. Movie',
#   'release_year': 2023,
#   'box_office': 1362566989,
#   'film_link': '/wiki/The_Super_Mario_Bros._Movie'},
#  {'title': 'Black Panther',
#   'release_year': 2018,
#   'box_office': 1347280838,
#   'film_link': '/wiki/Black_Panther_(film)'},
#  {'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'release_year': 2011,
#   'box_office': 1342139727,
#   'film_link': '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2'},
#  {'title': 'Deadpool & Wolverine',
#   'release_year': 2024,
#   'box_office': 1338073645,
#   'film_link': '/wiki/Deadpool_%26_Wolverine'},
#  {'title': 'Star Wars: The Last Jedi',
#   'release_year': 2017,
#   'box_office': 1332539889,
#   'film_link': '/wiki/Star_Wars:_The_Last_Jedi'},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'release_year': 2018,
#   'box_office': 1308473425,
#   'film_link': '/wiki/Jurassic_World:_Fallen_Kingdom'},
#  {'title': 'Frozen',
#   'release_year': 2013,
#   'box_office': 1290000000,
#   'film_link': '/wiki/Frozen_(2013_film)'},
#  {'title': 'Beauty and the Beast',
#   'release_year': 2017,
#   'box_office': 1263521126,
#   'film_link': '/wiki/Beauty_and_the_Beast_(2017_film)'},
#  {'title': 'Incredibles 2',
#   'release_year': 2018,
#   'box_office': 1242805359,
#   'film_link': '/wiki/Incredibles_2'},
#  {'title': 'The Fate of the Furious',
#   'release_year': 2017,
#   'box_office': 1238764765,
#   'film_link': '/wiki/The_Fate_of_the_Furious'},
#  {'title': 'Iron Man 3',
#   'release_year': 2013,
#   'box_office': 1214811252,
#   'film_link': '/wiki/Iron_Man_3'},
#  {'title': 'Minions',
#   'release_year': 2015,
#   'box_office': 1159444662,
#   'film_link': '/wiki/Minions_(film)'},
#  {'title': 'Captain America: Civil War',
#   'release_year': 2016,
#   'box_office': 1153337496,
#   'film_link': '/wiki/Captain_America:_Civil_War'},
#  {'title': 'Aquaman',
#   'release_year': 2018,
#   'box_office': 1148528393,
#   'film_link': '/wiki/Aquaman_(film)'},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'release_year': 2003,
#   'box_office': 1147997407,
#   'film_link': '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King'},
#  {'title': 'Spider-Man: Far From Home',
#   'release_year': 2019,
#   'box_office': 1132679685,
#   'film_link': '/wiki/Spider-Man:_Far_From_Home'},
#  {'title': 'Captain Marvel',
#   'release_year': 2019,
#   'box_office': 1128274794,
#   'film_link': '/wiki/Captain_Marvel_(film)'},
#  {'title': 'Transformers: Dark of the Moon',
#   'release_year': 2011,
#   'box_office': 1123794079,
#   'film_link': '/wiki/Transformers:_Dark_of_the_Moon'},
#  {'title': 'Skyfall',
#   'release_year': 2012,
#   'box_office': 1108594137,
#   'film_link': '/wiki/Skyfall'},
#  {'title': 'Transformers: Age of Extinction',
#   'release_year': 2014,
#   'box_office': 1104054072,
#   'film_link': '/wiki/Transformers:_Age_of_Extinction'},
#  {'title': 'The Dark Knight Rises',
#   'release_year': 2012,
#   'box_office': 1081169825,
#   'film_link': '/wiki/The_Dark_Knight_Rises'},
#  {'title': 'Joker',
#   'release_year': 2019,
#   'box_office': 1074458282,
#   'film_link': '/wiki/Joker_(2019_film)'},
#  {'title': 'Star Wars: The Rise of Skywalker',
#   'release_year': 2019,
#   'box_office': 1074144248,
#   'film_link': '/wiki/Star_Wars:_The_Rise_of_Skywalker'},
#  {'title': 'Toy Story 4',
#   'release_year': 2019,
#   'box_office': 1073394593,
#   'film_link': '/wiki/Toy_Story_4'},
#  {'title': 'Toy Story 3',
#   'release_year': 2010,
#   'box_office': 1066970811,
#   'film_link': '/wiki/Toy_Story_3'},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'release_year': 2006,
#   'box_office': 1066179747,
#   'film_link': '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest'},
#  {'title': 'Rogue One: A Star Wars Story',
#   'release_year': 2016,
#   'box_office': 1057420387,
#   'film_link': '/wiki/Rogue_One:_A_Star_Wars_Story'},
#  {'title': 'Moana 2',
#   'release_year': 2024,
#   'box_office': 1053502480,
#   'film_link': '/wiki/Moana_2'},
#  {'title': 'Aladdin',
#   'release_year': 2019,
#   'box_office': 1050693953,
#   'film_link': '/wiki/Aladdin_(2019_film)'},
#  {'title': 'Star Wars: Episode I – The Phantom Menace',
#   'release_year': 1999,
#   'box_office': 1046515409,
#   'film_link': '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace'},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'release_year': 2011,
#   'box_office': 1045713802,
#   'film_link': '/wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides'},
#  {'title': 'Jurassic Park',
#   'release_year': 1993,
#   'box_office': 1037535230,
#   'film_link': '/wiki/Jurassic_Park_(film)'},
#  {'title': 'Despicable Me 3',
#   'release_year': 2017,
#   'box_office': 1034800131,
#   'film_link': '/wiki/Despicable_Me_3'}]

# %%
base_url = "https://en.wikipedia.org"

# extract director(s) and country from individual film page
def get_additional_details(film_link):
    # access by url
    film_url = base_url + film_link
    response = requests.get(film_url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page for {film_url}. Status code: {response.status_code}")
        return None, None

    film_soup = BeautifulSoup(response.text, 'html.parser')

    director = None
    country = None
    # retrieving infobox on the side
    infobox = film_soup.find('table', {'class': 'infobox'})
    if infobox:
        director_row = infobox.find('th', string='Directed by')
        if director_row:
            director = director_row.find_next_sibling('td').get_text(separator=', ', strip=True)
            # because citations look awful in parsed data
            director = ', '.join([d for d in director.split(", ") if d.replace(" ", "").replace(".", "").isalpha()])

        country_row = infobox.find('th', string='Country')
        if country_row:
            country = country_row.find_next_sibling('td').get_text(separator=', ', strip=True)
        if not country:
            country_row = infobox.find('th', string='Countries')
            if country_row:    # taking only the first country (was told to do so in the chat)
                country = country_row.find_next_sibling('td').get_text(separator=', ', strip=True).split(",")[0]

    return director, country

for film in films_data:
    director, country = get_additional_details(film['film_link'])
    film['director'] = director
    film['country'] = country

# %%
films_data
# Out:
# [{'title': 'Avatar',
#   'release_year': 2009,
#   'box_office': 2923706026,
#   'film_link': '/wiki/Avatar_(2009_film)',
#   'director': 'James Cameron',
#   'country': 'United Kingdom'},
#  {'title': 'Avengers: Endgame',
#   'release_year': 2019,
#   'box_office': 2797501328,
#   'film_link': '/wiki/Avengers:_Endgame',
#   'director': 'Anthony Russo, Joe Russo',
#   'country': 'United States'},
#  {'title': 'Avatar: The Way of Water',
#   'release_year': 2022,
#   'box_office': 2320250281,
#   'film_link': '/wiki/Avatar:_The_Way_of_Water',
#   'director': 'James Cameron',
#   'country': 'United States'},
#  {'title': 'Titanic',
#   'release_year': 1997,
#   'box_office': 2257844554,
#   'film_link': '/wiki/Titanic_(1997_film)',
#   'director': 'James Cameron',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Force Awakens',
#   'release_year': 2015,
#   'box_office': 2068223624,
#   'film_link': '/wiki/Star_Wars:_The_Force_Awakens',
#   'director': 'J. J. Abrams',
#   'country': 'United States'},
#  {'title': 'Avengers: Infinity War',
#   'release_year': 2018,
#   'box_office': 2048359754,
#   'film_link': '/wiki/Avengers:_Infinity_War',
#   'director': 'Anthony Russo, Joe Russo',
#   'country': 'United States'},
#  {'title': 'Ne Zha 2',
#   'release_year': 2025,
#   'box_office': 1940794560,
#   'film_link': '/wiki/Ne_Zha_2',
#   'director': 'Jiaozi',
#   'country': 'China'},
#  {'title': 'Spider-Man: No Way Home',
#   'release_year': 2021,
#   'box_office': 1922598800,
#   'film_link': '/wiki/Spider-Man:_No_Way_Home',
#   'director': 'Jon Watts',
#   'country': 'United States'},
#  {'title': 'Inside Out 2',
#   'release_year': 2024,
#   'box_office': 1698863816,
#   'film_link': '/wiki/Inside_Out_2',
#   'director': 'Kelsey Mann',
#   'country': 'United States'},
#  {'title': 'Jurassic World',
#   'release_year': 2015,
#   'box_office': 1671537444,
#   'film_link': '/wiki/Jurassic_World',
#   'director': 'Colin Trevorrow',
#   'country': 'United States'},
#  {'title': 'The Lion King',
#   'release_year': 2019,
#   'box_office': 1656943394,
#   'film_link': '/wiki/The_Lion_King_(2019_film)',
#   'director': 'Jon Favreau',
#   'country': 'United States'},
#  {'title': 'The Avengers',
#   'release_year': 2012,
#   'box_office': 1518815515,
#   'film_link': '/wiki/The_Avengers_(2012_film)',
#   'director': 'Joss Whedon',
#   'country': 'United States'},
#  {'title': 'Furious 7',
#   'release_year': 2015,
#   'box_office': 1515341399,
#   'film_link': '/wiki/Furious_7',
#   'director': 'James Wan',
#   'country': 'United States'},
#  {'title': 'Top Gun: Maverick',
#   'release_year': 2022,
#   'box_office': 1495696292,
#   'film_link': '/wiki/Top_Gun:_Maverick',
#   'director': 'Joseph Kosinski',
#   'country': 'United States'},
#  {'title': 'Frozen 2',
#   'release_year': 2019,
#   'box_office': 1450026933,
#   'film_link': '/wiki/Frozen_2',
#   'director': 'Chris Buck, Jennifer Lee',
#   'country': 'United States'},
#  {'title': 'Barbie',
#   'release_year': 2023,
#   'box_office': 1447038421,
#   'film_link': '/wiki/Barbie_(film)',
#   'director': 'Greta Gerwig',
#   'country': 'United States'},
#  {'title': 'Avengers: Age of Ultron',
#   'release_year': 2015,
#   'box_office': 1402809540,
#   'film_link': '/wiki/Avengers:_Age_of_Ultron',
#   'director': 'Joss Whedon',
#   'country': 'United States'},
#  {'title': 'The Super Mario Bros. Movie',
#   'release_year': 2023,
#   'box_office': 1362566989,
#   'film_link': '/wiki/The_Super_Mario_Bros._Movie',
#   'director': 'Aaron Horvath, Michael Jelenic',
#   'country': 'United States'},
#  {'title': 'Black Panther',
#   'release_year': 2018,
#   'box_office': 1347280838,
#   'film_link': '/wiki/Black_Panther_(film)',
#   'director': 'Ryan Coogler',
#   'country': 'United States'},
#  {'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'release_year': 2011,
#   'box_office': 1342139727,
#   'film_link': '/wiki/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2',
#   'director': 'David Yates',
#   'country': 'United Kingdom'},
#  {'title': 'Deadpool & Wolverine',
#   'release_year': 2024,
#   'box_office': 1338073645,
#   'film_link': '/wiki/Deadpool_%26_Wolverine',
#   'director': 'Shawn Levy',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Last Jedi',
#   'release_year': 2017,
#   'box_office': 1332539889,
#   'film_link': '/wiki/Star_Wars:_The_Last_Jedi',
#   'director': 'Rian Johnson',
#   'country': 'United States'},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'release_year': 2018,
#   'box_office': 1308473425,
#   'film_link': '/wiki/Jurassic_World:_Fallen_Kingdom',
#   'director': 'J. A. Bayona',
#   'country': 'China'},
#  {'title': 'Frozen',
#   'release_year': 2013,
#   'box_office': 1290000000,
#   'film_link': '/wiki/Frozen_(2013_film)',
#   'director': 'Chris Buck, Jennifer Lee',
#   'country': 'United States'},
#  {'title': 'Beauty and the Beast',
#   'release_year': 2017,
#   'box_office': 1263521126,
#   'film_link': '/wiki/Beauty_and_the_Beast_(2017_film)',
#   'director': 'Bill Condon',
#   'country': 'United States'},
#  {'title': 'Incredibles 2',
#   'release_year': 2018,
#   'box_office': 1242805359,
#   'film_link': '/wiki/Incredibles_2',
#   'director': 'Brad Bird',
#   'country': 'United States'},
#  {'title': 'The Fate of the Furious',
#   'release_year': 2017,
#   'box_office': 1238764765,
#   'film_link': '/wiki/The_Fate_of_the_Furious',
#   'director': 'F. Gary Gray',
#   'country': 'United States'},
#  {'title': 'Iron Man 3',
#   'release_year': 2013,
#   'box_office': 1214811252,
#   'film_link': '/wiki/Iron_Man_3',
#   'director': 'Shane Black',
#   'country': 'United States'},
#  {'title': 'Minions',
#   'release_year': 2015,
#   'box_office': 1159444662,
#   'film_link': '/wiki/Minions_(film)',
#   'director': 'Pierre Coffin, Kyle Balda',
#   'country': 'United States'},
#  {'title': 'Captain America: Civil War',
#   'release_year': 2016,
#   'box_office': 1153337496,
#   'film_link': '/wiki/Captain_America:_Civil_War',
#   'director': 'Anthony Russo, Joe Russo',
#   'country': 'United States'},
#  {'title': 'Aquaman',
#   'release_year': 2018,
#   'box_office': 1148528393,
#   'film_link': '/wiki/Aquaman_(film)',
#   'director': 'James Wan',
#   'country': 'United States'},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'release_year': 2003,
#   'box_office': 1147997407,
#   'film_link': '/wiki/The_Lord_of_the_Rings:_The_Return_of_the_King',
#   'director': 'Peter Jackson',
#   'country': 'New Zealand'},
#  {'title': 'Spider-Man: Far From Home',
#   'release_year': 2019,
#   'box_office': 1132679685,
#   'film_link': '/wiki/Spider-Man:_Far_From_Home',
#   'director': 'Jon Watts',
#   'country': 'United States'},
#  {'title': 'Captain Marvel',
#   'release_year': 2019,
#   'box_office': 1128274794,
#   'film_link': '/wiki/Captain_Marvel_(film)',
#   'director': 'Anna Boden, Ryan Fleck',
#   'country': 'United States'},
#  {'title': 'Transformers: Dark of the Moon',
#   'release_year': 2011,
#   'box_office': 1123794079,
#   'film_link': '/wiki/Transformers:_Dark_of_the_Moon',
#   'director': 'Michael Bay',
#   'country': 'United States'},
#  {'title': 'Skyfall',
#   'release_year': 2012,
#   'box_office': 1108594137,
#   'film_link': '/wiki/Skyfall',
#   'director': 'Sam Mendes',
#   'country': 'United Kingdom'},
#  {'title': 'Transformers: Age of Extinction',
#   'release_year': 2014,
#   'box_office': 1104054072,
#   'film_link': '/wiki/Transformers:_Age_of_Extinction',
#   'director': 'Michael Bay',
#   'country': 'United States'},
#  {'title': 'The Dark Knight Rises',
#   'release_year': 2012,
#   'box_office': 1081169825,
#   'film_link': '/wiki/The_Dark_Knight_Rises',
#   'director': 'Christopher Nolan',
#   'country': 'United States'},
#  {'title': 'Joker',
#   'release_year': 2019,
#   'box_office': 1074458282,
#   'film_link': '/wiki/Joker_(2019_film)',
#   'director': 'Todd Phillips',
#   'country': 'United States'},
#  {'title': 'Star Wars: The Rise of Skywalker',
#   'release_year': 2019,
#   'box_office': 1074144248,
#   'film_link': '/wiki/Star_Wars:_The_Rise_of_Skywalker',
#   'director': 'J. J. Abrams',
#   'country': 'United States'},
#  {'title': 'Toy Story 4',
#   'release_year': 2019,
#   'box_office': 1073394593,
#   'film_link': '/wiki/Toy_Story_4',
#   'director': 'Josh Cooley',
#   'country': 'United States'},
#  {'title': 'Toy Story 3',
#   'release_year': 2010,
#   'box_office': 1066970811,
#   'film_link': '/wiki/Toy_Story_3',
#   'director': 'Lee Unkrich',
#   'country': 'United States'},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'release_year': 2006,
#   'box_office': 1066179747,
#   'film_link': '/wiki/Pirates_of_the_Caribbean:_Dead_Man%27s_Chest',
#   'director': 'Gore Verbinski',
#   'country': 'United States'},
#  {'title': 'Rogue One: A Star Wars Story',
#   'release_year': 2016,
#   'box_office': 1057420387,
#   'film_link': '/wiki/Rogue_One:_A_Star_Wars_Story',
#   'director': 'Gareth Edwards',
#   'country': 'United States'},
#  {'title': 'Moana 2',
#   'release_year': 2024,
#   'box_office': 1053502480,
#   'film_link': '/wiki/Moana_2',
#   'director': 'David Derrick Jr., Jason Hand, Dana Ledoux Miller',
#   'country': 'United States'},
#  {'title': 'Aladdin',
#   'release_year': 2019,
#   'box_office': 1050693953,
#   'film_link': '/wiki/Aladdin_(2019_film)',
#   'director': 'Guy Ritchie',
#   'country': 'United States'},
#  {'title': 'Star Wars: Episode I – The Phantom Menace',
#   'release_year': 1999,
#   'box_office': 1046515409,
#   'film_link': '/wiki/Star_Wars:_Episode_I_%E2%80%93_The_Phantom_Menace',
#   'director': 'George Lucas',
#   'country': 'United States'},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'release_year': 2011,
#   'box_office': 1045713802,
#   'film_link': '/wiki/Pirates_of_the_Caribbean:_On_Stranger_Tides',
#   'director': 'Rob Marshall',
#   'country': 'United States'},
#  {'title': 'Jurassic Park',
#   'release_year': 1993,
#   'box_office': 1037535230,
#   'film_link': '/wiki/Jurassic_Park_(film)',
#   'director': 'Steven Spielberg',
#   'country': 'United States'},
#  {'title': 'Despicable Me 3',
#   'release_year': 2017,
#   'box_office': 1034800131,
#   'film_link': '/wiki/Despicable_Me_3',
#   'director': 'Pierre Coffin, Kyle Balda',
#   'country': 'United States'}]

# %%
# either connect or create db
conn = sqlite3.connect('films.db')
cursor = conn.cursor()

# Create the films table
cursor.execute('''
CREATE TABLE IF NOT EXISTS films (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    release_year INTEGER,
    director TEXT,
    box_office TEXT,
    country TEXT
)
''')

films_to_insert = [
    (film['title'], film['release_year'], film['director'], film['box_office'], film['country'])
    for film in films_data
]

# insert data into the table
cursor.executemany('''
INSERT INTO films (title, release_year, director, box_office, country)
VALUES (?, ?, ?, ?, ?)
''', films_to_insert)

conn.commit()

# view the table we created
cursor.execute("SELECT * FROM films")
rows = cursor.fetchall()
for row in rows:
    print(row)

conn.close()
# Out:
# (1, 'Avatar', 2009, 'James Cameron', '2923706026', 'United Kingdom')
# (2, 'Avengers: Endgame', 2019, 'Anthony Russo, Joe Russo', '2797501328', 'United States')
# (3, 'Avatar: The Way of Water', 2022, 'James Cameron', '2320250281', 'United States')
# (4, 'Titanic', 1997, 'James Cameron', '2257844554', 'United States')
# (5, 'Star Wars: The Force Awakens', 2015, 'J. J. Abrams', '2068223624', 'United States')
# (6, 'Avengers: Infinity War', 2018, 'Anthony Russo, Joe Russo', '2048359754', 'United States')
# (7, 'Ne Zha 2', 2025, 'Jiaozi', '1940794560', 'China')
# (8, 'Spider-Man: No Way Home', 2021, 'Jon Watts', '1922598800', 'United States')
# (9, 'Inside Out 2', 2024, 'Kelsey Mann', '1698863816', 'United States')
# (10, 'Jurassic World', 2015, 'Colin Trevorrow', '1671537444', 'United States')
# (11, 'The Lion King', 2019, 'Jon Favreau', '1656943394', 'United States')
# (12, 'The Avengers', 2012, 'Joss Whedon', '1518815515', 'United States')
# (13, 'Furious 7', 2015, 'James Wan', '1515341399', 'United States')
# (14, 'Top Gun: Maverick', 2022, 'Joseph Kosinski', '1495696292', 'United States')
# (15, 'Frozen 2', 2019, 'Chris Buck, Jennifer Lee', '1450026933', 'United States')
# (16, 'Barbie', 2023, 'Greta Gerwig', '1447038421', 'United States')
# (17, 'Avengers: Age of Ultron', 2015, 'Joss Whedon', '1402809540', 'United States')
# (18, 'The Super Mario Bros. Movie', 2023, 'Aaron Horvath, Michael Jelenic', '1362566989', 'United States')
# (19, 'Black Panther', 2018, 'Ryan Coogler', '1347280838', 'United States')
# (20, 'Harry Potter and the Deathly Hallows – Part 2', 2011, 'David Yates', '1342139727', 'United Kingdom')
# (21, 'Deadpool & Wolverine', 2024, 'Shawn Levy', '1338073645', 'United States')
# (22, 'Star Wars: The Last Jedi', 2017, 'Rian Johnson', '1332539889', 'United States')
# (23, 'Jurassic World: Fallen Kingdom', 2018, 'J. A. Bayona', '1308473425', 'China')
# (24, 'Frozen', 2013, 'Chris Buck, Jennifer Lee', '1290000000', 'United States')
# (25, 'Beauty and the Beast', 2017, 'Bill Condon', '1263521126', 'United States')
# (26, 'Incredibles 2', 2018, 'Brad Bird', '1242805359', 'United States')
# (27, 'The Fate of the Furious', 2017, 'F. Gary Gray', '1238764765', 'United States')
# (28, 'Iron Man 3', 2013, 'Shane Black', '1214811252', 'United States')
# (29, 'Minions', 2015, 'Pierre Coffin, Kyle Balda', '1159444662', 'United States')
# (30, 'Captain America: Civil War', 2016, 'Anthony Russo, Joe Russo', '1153337496', 'United States')
# (31, 'Aquaman', 2018, 'James Wan', '1148528393', 'United States')
# (32, 'The Lord of the Rings: The Return of the King', 2003, 'Peter Jackson', '1147997407', 'New Zealand')
# (33, 'Spider-Man: Far From Home', 2019, 'Jon Watts', '1132679685', 'United States')
# (34, 'Captain Marvel', 2019, 'Anna Boden, Ryan Fleck', '1128274794', 'United States')
# (35, 'Transformers: Dark of the Moon', 2011, 'Michael Bay', '1123794079', 'United States')
# (36, 'Skyfall', 2012, 'Sam Mendes', '1108594137', 'United Kingdom')
# (37, 'Transformers: Age of Extinction', 2014, 'Michael Bay', '1104054072', 'United States')
# (38, 'The Dark Knight Rises', 2012, 'Christopher Nolan', '1081169825', 'United States')
# (39, 'Joker', 2019, 'Todd Phillips', '1074458282', 'United States')
# (40, 'Star Wars: The Rise of Skywalker', 2019, 'J. J. Abrams', '1074144248', 'United States')
# (41, 'Toy Story 4', 2019, 'Josh Cooley', '1073394593', 'United States')
# (42, 'Toy Story 3', 2010, 'Lee Unkrich', '1066970811', 'United States')
# (43, "Pirates of the Caribbean: Dead Man's Chest", 2006, 'Gore Verbinski', '1066179747', 'United States')
# (44, 'Rogue One: A Star Wars Story', 2016, 'Gareth Edwards', '1057420387', 'United States')
# (45, 'Moana 2', 2024, 'David Derrick Jr., Jason Hand, Dana Ledoux Miller', '1053502480', 'United States')
# (46, 'Aladdin', 2019, 'Guy Ritchie', '1050693953', 'United States')
# (47, 'Star Wars: Episode I – The Phantom Menace', 1999, 'George Lucas', '1046515409', 'United States')
# (48, 'Pirates of the Caribbean: On Stranger Tides', 2011, 'Rob Marshall', '1045713802', 'United States')
# (49, 'Jurassic Park', 1993, 'Steven Spielberg', '1037535230', 'United States')
# (50, 'Despicable Me 3', 2017, 'Pierre Coffin, Kyle Balda', '1034800131', 'United States')

# %% [markdown]
# # Part 2: Web Page Development and GitHub Pages Hosting

# %%
import sqlite3
import json

conn = sqlite3.connect("films.db")
cursor = conn.cursor()

cursor.execute("SELECT title, release_year, director, box_office, country FROM films;")
films = cursor.fetchall()

# tuples to a list of dictionaries
films_list = [{"title": row[0], "release_year": row[1], "director": row[2], "box_office": row[3], "country": row[4]} for row in films]

with open("films.json", "w", encoding="utf-8") as f:
    json.dump(films_list, f, indent=4)

conn.close()
